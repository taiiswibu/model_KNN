# %% [markdown]
# #Bài tập code cơ bản

# %% [markdown]
# Chương trình tính tổng 2 số tự nhiên a và b.

# %%
def tinhtong(a,b):
    tong = a +b
    print(" tong cua {0} + {1} = {2} ".format(a,b,tong))    
    return 

tinhtong(3,6)
# Out:
#  tong cua 3 + 6 = 9

# %% [markdown]
# Em hãy viết chương trình nhập vào 1 dãy số tự nhiên với N số. Sắp xếp các số tự nhiên theo thứ tự tăng dần.

# %%
arr = []
n = int(input("nhap phan tu n:"))
for i in range(n):
    a = int(input("hay nhap mot day so tu nhien"))
    arr.append(a)
    arr.sort()
print(arr)
# Out:
# [1, 2, 3, 4, 7]

# %% [markdown]
# Em hãy viết chương trình giải phương trình bậc 2

# %%
a= float(input("Nhap a:"))
b= float(input("Nhap b:"))
c= float(input("Nhap c:"))

delta = b*b - 4*a*c

if a == 0:
    if b == 0:
        print("Phuong trinh vo nghiem")
    else:
        print ("Phương trình có một nghiệm: x = ", + (-c / b));   
else:
    if delta <0:
        print("phuong trinh vo nghiem")
    elif delta == 0:
        print("Phuong trinh co nghiem kep x1 = x2",-(b/2*a))
    else:
        x1 = -(b+ delta) / 2*a
        x2 = -(b- delta) / 2*a
        print("phuong trinh co hai nghiem phan biet x1 =",x1,"va x2 = ",x2)
# Out:
# phuong trinh vo nghiem

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.arange(10)

for i in range(1,4):
    plt.plot(x,i * x**2 , label= 'Group %d' % i)

plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
